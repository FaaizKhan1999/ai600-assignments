# %% [markdown]
# # Task 1: Linear, Polynomial, and Kernel-Based Regression

# %%
import pandas as pd

# %%
df = pd.read_csv('data-a1.csv')
df.head
# Out:
# <bound method NDFrame.head of         addref        city  assembly         body      make    model    year  \
# 0      7642697   Islamabad       NaN  Compact SUV       KIA  Sorento  2021.0
# 1      7909608   Sadiqabad  Imported    Hatchback  Daihatsu     Mira  2020.0
# 2      7929224    Peshawar  Imported    Hatchback    Toyota     Vitz  2018.0
# 3      7832366      Lahore       NaN        Sedan    Toyota  Corolla  2019.0
# 4      7866725   Islamabad       NaN        Sedan    Toyota  Corolla  2022.0
# ...        ...         ...       ...          ...       ...      ...     ...
# 62297  7791453  Bahawalpur       NaN          NaN    Suzuki   Cultus  2017.0
# 62298  7386831    Peshawar       NaN    Hatchback    Suzuki   Cultus  2016.0
# 62299  7937377      Lahore       NaN    Hatchback    Suzuki    Wagon  2020.0
# 62300  7800049  Rawalpindi       NaN    Hatchback    Suzuki     Alto  2021.0
# 62301  7827341      Multan       NaN  Compact SUV   Changan    Oshan     NaN
#
# ...
